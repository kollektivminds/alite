# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from sqlalchemy import create_engine, text
from dotenv import load_dotenv
import alite_backend
from alite_backend.db.db_session import engine
from alite_backend.db.models import Base
from alite_backend.words.funcs import *
from alite_backend.db import *
#from .. words.ews import *
from alite_backend.words.pipeline import feed_data

# %%
print(alite_backend.__file__)
# Out:
# /Users/aaron.thompson/code/alite/app/backend/src/alite_backend/__init__.py
